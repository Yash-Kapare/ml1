# %%
print("Updated")
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# Out:
# MLOps Practical 1
# Updated from clone

# %%
data=pd.read_csv(r"C:\Users\yashk\OneDrive\Desktop\MLOPS Pr1\3.2 cost_revenue_clean.csv")
data.describe
# Out:
# <bound method NDFrame.describe of       production_budget_usd  worldwide_gross_usd
# 0                   1000000                   26
# 1                     10000                  401
# 2                    400000                  423
# 3                    750000                  450
# 4                     10000                  527
# ...                     ...                  ...
# 5029              225000000           1519479547
# 5030              215000000           1671640593
# 5031              306000000           2058662225
# 5032              200000000           2207615668
# 5033              425000000           2783918982
#
# [5034 rows x 2 columns]>

# %%
X = DataFrame(data, columns=['production_budget_usd'])
y = DataFrame(data, columns=['worldwide_gross_usd'])

# %%
regression = LinearRegression()
regression.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# Slope Coefficient

# %%
regression.coef_
# Out:
# array([[3.11150918]])

# %%
regression.intercept_
# Out:
# array([-7236192.72913963])

# %%
plt.figure(figsize=(10,6))
plt.scatter(X,y,alpha=0.3)
plt.plot(X, regression.predict(X), color= 'purple', linewidth=5)
plt.title('Film cost vs Global Revenue')
plt.xlabel('Production Budget')
plt.ylabel('Worldwide Gross')
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
plt.show()

# %% [markdown]
# R-square score

# %%
regression.score(X,y)
# Out:
# 0.5496485356985727
